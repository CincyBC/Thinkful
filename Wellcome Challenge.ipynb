# %%
"""The assignment is to do the following:
1) Determine the 5 most common journals
2) The number of articles from each.
3) The mean, median, and std of the open access articles cost
4) Challenge: Determine the prices paid by subject area"""
# Out:
# 'The assignment is to do the following:\n1) Determine the 5 most common journals\n2) The number of articles from each.\n3) The mean, median, and std of the open access articles cost\n4) Challenge: Determine the prices paid by subject area'

# %%
import numpy as np
import pandas as pd

# %%
#Import the CSV and found an encoding problem. Solved it by setting the encoding to ISO-8859-1.
wellcome_df = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', encoding = "ISO-8859-1")
#Make the column name cleaner for the Cost column
wellcome_df = wellcome_df.rename(index=str, columns={"COST (£) charged to Wellcome (inc VAT when charged)": "Cost"})

print(wellcome_df)
# Out:
#                             PMID/PMCID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# ...

# %%
#Looking at the Publisher list, we can see all of the unique values that aren't really unique. We need to clean the names.
wellcome_df['Publisher'].unique()
# Out:
# array(['CUP', 'ACS', 'ACS (Amercian Chemical Society) Publications',
#        'ACS Publications', 'AGA Institute', 'AMBSB',
#        'American Association of Immunologists',
#        'American Chemical Society', 'AMERICAN CHEMICAL SOCIETY',
#        'American Chemical Society Publications',
#        'American College of Chest Physicians',
#        'American Physiological Society',
#        'American Psychiatric Association',
#        'American Psychiatric Publishing',
#        'American Psychological Association',
#        'American Psychological Association ',
#        'American Public Health Association',
#        'American Soc for Biochemistry and Molecular Biology',
#        'American Society for Biochemistry and Molecular Biolgy',
#        'American Society for Biochemistry and Molecular Biology',
#        'American Society for Biochemistry and Molecular Biology ',
#        'American Society for Investigative Pathology',
#        'American Society for Microbiology',
# ...

# %%
#Let's first remove all of the whitespace at the beginning and ends of words
wellcome_df['Publisher'] = wellcome_df['Publisher'].str.strip()

#Next, let's take out the redundancies from capital letters by only capitalizing the first letter.
wellcome_df['Publisher'] = wellcome_df['Publisher'].str.capitalize()

#Next, let's replace the & with 'and'
wellcome_df['Publisher'] = wellcome_df['Publisher'].str.replace('&', 'and')

# %%
#Then, let's consolidate.
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['ACS (American Chemical Society) Publications', 'American Chemical Society Publications',
                                                             'ACS Publications', 'American Chemical Society', 'ACS (Amercian Chemical Society) Publications',
                                                             'AMERICAN CHEMICAL SOCIETY', 'ACS','ACS (Amercian Chemical Society) Publications'],'American chemical society')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['American Psychological Association '], 'American psychological association')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['American Society for Microbiology ','American Society of Microbiology ',
       'American Society for Microbiology \n', 'ASM', 'ASM (American Society for Microbiology)', 'American Society of Microbiology'],'American society for microbiology') 
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['American Soc for Biochemistry and Molecular Biology',
       'American Society for Biochemistry and Molecular Biolgy',
       'American Society for Biochemistry and Molecular Biology',
       'American Society for Biochemistry and Molecular Biology ','The american society for biochemistry and molecular biology',
       'The American Society for Biochemistry and Molecular Biology, Inc', 'AMBSB','ASBMB Cadmus',
       'ASBMB/Cadmus', 'ASBMB/Cenveo Publisher Services', 'ASBMC /CENVEO'], 'Asbmb')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['American Society of Haematology',
       'American Society of Hamatology', 'American Society of hematology'], 'American society of hematology')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Benthan Science Publishers'], 'Bentham science publishers')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace([
       'BioMed central', 'Biomed Central', 'BioMed Central ',
       'BioMed Central Limited', 'BioMed Central Ltd'], 'Biomed central')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace([
       'BMJ ', 'BMJ Group', 'BMJ group', 'BMJ Group ', 'Bmj journals',
       'BMJ Publishing Group', 'BMJ PUBLISHING GROUP',
       'BMJ Publishing Group Ltd',
       'BMJ Publishing Group Ltd & British Thoracic Society', 'Brill',
       'British Medical Journal', 'BMJ'], 'British medical journal')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Cadmus',
       'Cadmus ', 'CADMUS JOURNAL SERVICE ', 'Cadmus Journal Services',
       'CADMUS JOURNAL SERVICES','Camdus Journal Services'], 'Cadmus')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Cambridge journals',
       'Cambridge Uni Press', 'Cambridge Univ Press', 'Cup'], 'Cambridge university press')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Cenveo Publisher services',
       'Cenveo Publisher Services/ASM JV1'], 'Cenveo publisher services')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Cold spring habour press', 'Cold spring harbor',
       'Cold spring harbor laboratory press', 'Cold spring harbor press',
       'Cold spring harbor publications','Cshlp'], 'Cold spring harbor press')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['American society of human genetics (elsevier)','Elseveier science', 'Elsevier',
       'Elsevier (cell press)', 'Elsevier / cell science', 'Elsevier b.v.',
       'Elsevier ltd', 'Elsevier/cell press'], 'Elsevier')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Bioscientifica'], 'BioScientifica')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Company of biologist', 'Company of biologists',
       'Company of biologists ltd'], 'Company of Biologists')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Darmouth journal services', 'Dartmouth journal services',
       'Dartmouth journal services ', 'Dartmouth journals'], 'Dartmouth Journal Services')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['International union of crystallography',
       'International union of crystallography ',
       'International union of crystallography (iucr)'], 'International Union of Crystallography')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Oup', 'Oxford journals',
       'Oxford journals (oup)', 'Oxford univ press',
       'Oxford university press',
       'Oxford university press ', 'Oxford university press (oup)',
       'Oxford university press\n', 'Oxford univesity press',], 'Oxford university press')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Nature', 'Nature ',
       'Nature pg', 'Nature publishing', 'Nature publishing group',
       'Nature publishing group', 'Nature publishing group ',
       'Nature publishing group ltd', 'Npg'], 'Nature publishing group')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['National academy of sciences',
       'National academy of sciences',
       'National academy of sciences of the united states of america',
       'National academy of sciences usa',
       'National academy of sciences, usa'], 'National academy of sciences')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['My jove corp', 'My jove corporation',
       'Myjove corporation'], 'MY JOVE CORP')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['The american physiological society','American physiological association'], 'American Physiological Society')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['American psychiatric publishing'], 'American Psychiatric Association')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Faseb',
       'Federation of american societies for experimental biology',
       'Federation of american societies for experimental biology (faseb)',
       'Federation of the american society of experimental biology'], 'FASEB')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Royal society', 'Royal society for chemistry',
       'Royal society of chemistry', 'Rsc', 'Rsc publishing'], 'Royal Society of Chemistry')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Hindawi', 'Hindawi publishing corporation'], 'Hindawi')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['International union against tuberculosis and lung disease',
       'International union against tuberculosis and lung disease'], 'International union against tuberculosis and lung disease')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Sage', 'Sage publications',
       'SAGE publications', 'Sage publications inc',
       'Sage publications ltd', 'Sage publishers', 'Sage publishing'], "Sage publications")
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Plos',
       'Plos', 'Plos', 'Plos (public library of science)',
       'Plos public library of science'], 'PLOS')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Frontiers', 'Frontiers media',
       'Frontiers media sa', 'Frontiers research foundation'], 'Frontiers')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['The journal of visualized experiments', 'Jove'], 'Journal of visualized experiments') 
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Landes bioscience', 'Landes biosciences'], 'Landes bioscience')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Mary ann liebert', 'Mary ann liebert inc',
       'Mary ann liebert, inc. publishers'], 'Mary ann liebert')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Mit press','Mit press open access'], 'MIT Press')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Impact Journals','Impact Journals LLC'], 'Impact Journals') 
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Informa healthcare','Informa healthcare communications'], 'Informa healthcare')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Proceedings of the national academy of sciences (pnas)', 'Pnas author publication'], 'PNAS') 
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Portland press',
       'Portland press', 'Portland press ltd'], 'Portland press')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Society for general microbiology',
       'Society for genermal microbiology', 'Society of general microbiology'], 'Society for general microbiology')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Society for neurosciences','Society of neuro sciences', 'Society of neuroscience'], 'Society for neuroscience')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Springer', 'Springer - verlag gmbh',
       'Springer science + business media', 'Springer verlag',
       'Springer-veriag gmbh', 'Springer-verlag gmbh',
       'Springer-verlag gmbh', 'Springer-verlag gmbh and ci',
       'Springer-verlag Gmbh, heidelberger platz 3, d-14197 berlin', 'Tandf'], 'Springer')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Taylor and francis', 'Taylor & francis journals ',
       'Taylor and francis', 'Taylor and francis '], 'Taylor and francis')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Pubmed', 'Pubmed central'], 'Pubmed')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['The company of Biolgists', 'THE COMPANY OF BIOLOGISTS',
       'The company of Biologists', 'The company of biologists',
       'The company of biologists ltd'], 'The company of biologists')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['The Endocrine Socety',
       'The Endocrine Society', 'THE ENDOCRINE SOCIETY',
       'The Endrocrine society'], 'The endocrine society') 
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Wiley', 'Wiley ','John wiley', 'JOHN WILEY and SONS',
       'John wiley and sons', 'John wiley and sons inc',
       'John wiley and sons ltd', 'John wiley and sons, inc. ',
       'John wiley and sons', 'John wiley and sons ltd'
       'Wiley and son', 'Wiley blackwell', 'Wiley online library',
       'Wiley subscription services', 'Wiley subscription services  inc.',
       'Wiley subscription services inc',
       'Wiley subscription serviices inc', 'Wiley VCH', 'Wiley/blackwell',
       'Wiley-blackwell', 'Wiley-blackwell, John Wiley and sons',
       'Wiley-vch', 'Wliey-blackwell', 'Wiley and son', 'John Wiley and Sons Ltd'], "John Wiley")
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Wolters kluwer',
       'Wolters kluwer health', 'Wolters kluwer health ',
       'Wolters kluwer n.v./lippinott', 'Wolters kluwers'], 'Wolters kluwer health')
wellcome_df['Publisher'] = wellcome_df['Publisher'].replace(['Iop publishing'], 'Institute of physics')

# %%
#Check that we have consolidated the list to standard Publishers
wellcome_df['Publisher'].unique()
# Out:
# array(['Cambridge university press', 'Acs',
#        'Acs (amercian chemical society) publications', 'Acs publications',
#        'Aga institute', 'Ambsb', 'American association of immunologists',
#        'American chemical society',
#        'American chemical society publications',
#        'American college of chest physicians',
#        'American physiological society',
#        'American psychiatric association',
#        'American Psychiatric Association',
#        'American psychological association',
#        'American public health association',
#        'American soc for biochemistry and molecular biology',
#        'American society for biochemistry and molecular biolgy',
#        'American society for biochemistry and molecular biology',
#        'American society for investigative pathology',
#        'American society for microbiology',
#        'American society for nutrition', 'American society of haematology',
# ...

# %%
#Let's find the five most common journals defined as most occurring
#Answers are: 
#Elsevier                                                                             409
#Public Library of Science                                                            278
#John Wiley                                                                           266
#Oxford University press                                                              167
#Springer                                                                              94
#Nature Publishing Group                                                               81

wellcome_df['Publisher'].value_counts()
# Out:
# Elsevier                                                      409
# Public library of science                                     278
# John Wiley                                                    266
# Oxford university press                                       167
# Springer                                                       94
# Nature publishing group                                        81
# Biomed central                                                 60
# Asbmb                                                          47
# Frontiers                                                      32
# PLOS                                                           29
# Cambridge university press                                     29
# Royal Society of Chemistry                                     27
# Bmc                                                            26
# Bmj                                                            25
# ...

# %%
#Clean up the journal titles doing the same thing
#Clean up whitespace
wellcome_df['Journal title'] = wellcome_df['Journal title'].str.strip()

#Clean up the capital letters
wellcome_df['Journal title'] = wellcome_df['Journal title'].str.capitalize()

#Remove the & and replace with 'and'
wellcome_df['Journal title'] = wellcome_df['Journal title'].str.replace('&', 'and')

Elsevier = wellcome_df.loc[wellcome_df['Publisher'] == 'Elsevier']

# %%
Elsevier['Journal title'].unique()
# Out:
# array(['The american journal of human genetics', 'Neuroimage',
#        'Academy of nutrition and dietetics',
#        'American journal of geriatric psychiatry',
#        'American journal of human genetics',
#        'American journal of preventive medicine',
#        'Analytical biochemistry', 'Animal behaviour', 'Applied energy',
#        'Asian journal of psychiatry', 'Atherosclerosis',
#        'Bba - molecular basis of disease', 'Behavior research and therapy',
#        'Behaviour research and therapy', 'Behavioural brain research',
#        'Biochemical and biophysical research communications',
#        'Biochemical pharmacology',
#        'Biochimica et bioohysica acta - gene regulatory mechanisms',
#        'Biochimica et bioohysica acta - molecular basis of disease',
#        'Biochimica et biophysica acta - molecular basis of disease',
#        'Biochimica et biophysica acta (bba) - molecular cell research',
# ...

# %%
#Clean up the Elsevier titles
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Biological chemistry',
       'Biologicial chemistry', 'J biol chemistry','The journal of biological chemistry', 'Jnl biological chemistry',
       'Journal ciological chemistry', 'Journal of biol chem'], 'Journal of biological chemistry')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Hum resour health'], 'Human resources for health')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['The americal journal of human genetics',
       'The american journal of human genetics'], 'American journal of human genetics')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Journal of affective disorders',
       'Journal of affective disorders '], 'Journal of affective disorders')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace([
       'Journal of allergy and clinical immunology',
       'Journal of allergy and clinical immunology'], 'Journal of allergy and clinical immunology')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Int journal for parasitology',
        'International journal for parasitology','International journal of parasitology'], 'International journal of parasitology')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Gene',
        'Gene therapy'], 'Gene therapy')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Development cell', 'Developmental Cell'],'Developmental cell')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Consciousness and cognition',
       'Consciousness and Cognition'], 'Consciousness and cognition')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Bba - molecular basis of disease','Biochimica et bioohysica acta - gene regulatory mechanisms',
       'Biochimica et bioohysica acta - molecular basis of disease',
       'Biochimica et biophysica acta - molecular basis of disease',
       'Biochimica et biophysica acta (bba) - molecular cell research'], 'BBA')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Behavior research and therapy',
       'Behaviour research and therapy'], 'Behavior Research and Therapy')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Biological Psychiatry', 'Biological psychology'], 'Biological Psychiatry')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Febs Letters'],'Febs letters')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['J Mol Biol', 'Molecular biology', 'Mol bio'], 'Journal of Molecular Biology')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Lancet', 'Lancet global health'],'Lancet')
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['NeuroImage',
       'Neuroimage: clinical', 'Neuroimage: clinical',
       'Neuroimage: clinical', 'Neuroimage: clinical ', 'Neurolmage'], 'NeuroImage') 
wellcome_df['Journal title'] = wellcome_df['Journal title'].replace(['Neurophysiologia', 'Neuropsychologia'], 'Neurophysiologia')

# %%
wellcome_df['Journal title'].value_counts()

#Top Five Journals are:
#Plos one                                                 190
#Journal of biological chemistry                           67
#Neuroimage                                                29
#Nucleic acids research                                    26
#Plos pathogens                                            24
# Out:
# Plos one                                                                                     190
# Journal of biological chemistry                                                               67
# Neuroimage                                                                                    29
# Nucleic acids research                                                                        26
# Plos pathogens                                                                                24
# Plos genetics                                                                                 24
# Proceedings of the national academy of sciences                                               22
# Plos neglected tropical diseases                                                              20
# Nature communications                                                                         19
# Human molecular genetics                                                                      19
# ...

# %%
#Let's count the number of articles
plos_one = wellcome_df.loc[wellcome_df['Journal title'] == 'Plos one']
jbc = wellcome_df.loc[wellcome_df['Journal title'] == 'Journal of biological chemistry']
neuroimage = wellcome_df.loc[wellcome_df['Journal title'] == 'Neuroimage']
nar = wellcome_df.loc[wellcome_df['Journal title'] == 'Nucleic acids research']
Plos_pathogens = wellcome_df.loc[wellcome_df['Journal title'] == 'Plos pathogens']

plos_one['Article title'].value_counts()
#Length 189 + an extra 1 for the first one 190
# Out:
# Exclusive breastfeeding, diarrhoel morbidity and all-couse mortality in infnats of HIV infected                                                                                        2
# Global quantitative SILAC phosphoproteomics reveals differential phosphorylation is widespread between the procyclic and bloodstream form lifecycle stages of Trypanosoma brucei.      1
# Genome-wide association studies reveal a simple genetic basis of resistance to naturally coevolving viruses in Drosophila melanogaster\n                                               1
# LKB1 mediates the development of conventional and innate T cells via AMP-dependent kinase autonomous pathways.                                                                         1
# Understanding the Impact of subsidizing Artemisinin-based  Combination Therapies (ACTs) in the Retail Sector - Results from Focus Group Discussion in rural Kenya                      1
# ...

# %%
jbc['Article title'].value_counts()
#67 Articles
# Out:
# Annexin-1 interaction with FPR2/ALX                                                                                                                                                                                       1
# Structural Requirements for Recognition of Major Histocompatibility Complex Class II by Membrane-associated RING-CH (MARCH) Protein E3 Ligases                                                                            1
# Novel keto-phospholipids are generated by monocytes and macrophages. Detected in Cystic Fibrosis, and activate peroxisome proliferator-activated receptor-? (Manuscript #M405409)                                         1
# Visualization of structural changes accompanying activation of NMDA receptors using fast-scan AFM imaging                                                                                                                 1
# ...

# %%
neuroimage['Article title'].value_counts()
#29 articles
# Out:
# 5-HTTLPR  environment interplay and its effects on neural reactivity in adolescents                                                              1
# Anatomical connectivity and the resting state activity of large cortical networks                                                                 1
# A multivariate method to determine the dimensionality of neural representation from population activity                                           1
# Movement related dynamics of subthalmo-cortical alpha connectivity in Parkinson's Disease                                                         1
# Connectivity-based neurofeedback: dynamic causal modeling for real-time fMRI                                                                      1
# A quantitative meta-analysis and review of motor learning in the human brain                                                                      1
# ...

# %%
nar['Article title'].value_counts()
#26 articles
# Out:
# Splicing-coupled 3? end formation requires a terminal splice acceptor site, but not intron excision                                                                                                 1
# The splicing landscape is globally reprogrammed during male meiosis                                                                                                                                 1
# Protein kinase CK2 inactivates PRH/Hhex using multiple mechanisms to derepress VEGF signalling genes and promote cell survival                                                                      1
# New functional families (FunFams) in CATH to improve the mapping of conserved functional sites to 3D structures                                                                                     1
# Impact of Target Site Distribution for Type I Restriction Enzymes on the Evolution of Methicillin Resistant Staphylococcus aureus (MRSA) Populations                                                1
# ...

# %%
Plos_pathogens['Article title'].value_counts()
#24 articles
# Out:
# Strongyloidiasis and Infective Dermatitis Alter Human T Lymphotropic Virus-1 Clonality in vivo                                                            1
# Genome-wide Determinants of Proviral Targeting, Clonal Abundance and Expression in Natural HTLV-1 Infection                                               1
# Lung adenocarcinoma originates from retrovirus infection of proliferating type 2 pneumocytes during pulmonary post-natal development or tissue repair     1
# Induction of p16(INK4a) Is the Major Barrier to Proliferation when Epstein-Barr Virus (EBV) Transforms Primary B Cells into Lymphoblastoid Cell Lines.    1
# An Over expression screen of Toxoplasma Gondii Rab-GTPases reveals distinct transport routes to the micronemes                                            1
# The CLIP-domain serine protease homolog SPCLIP1 regulates complement recruitment to microbial surfaces in the malaria mosquito Anopheles gambiae          1
# ...

# %%
#Take away the Pound/dollar signs
plos_one['Cost'] = plos_one['Cost'].str.lstrip('£').astype(float)
jbc['Cost'] = jbc['Cost'].str.lstrip('£').astype(float)
neuroimage['Cost'] = neuroimage['Cost'].str.lstrip('£').astype(float)
nar['Cost'] = nar['Cost'].str.lstrip('£').astype(float)
Plos_pathogens['Cost'] = Plos_pathogens['Cost'].str.lstrip('£').str.rstrip('$').astype(float)
#Set the outliers to more normal numbers
plos_one.ix[plos_one['Cost'] > 20000, 'Cost'] = 960
jbc.ix[jbc['Cost'] > 20000, 'Cost'] = 1500
neuroimage.ix[neuroimage['Cost'] > 20000, 'Cost'] = 2000
nar.ix[nar['Cost'] > 20000, 'Cost'] = 1400
Plos_pathogens.ix[Plos_pathogens['Cost'] > 20000, 'Cost'] = 1500
#Now we print out the mean, median, and standard deviation for each.
print("This is Plos One's mean {}, median {}, and standard deviation {}".format(plos_one['Cost'].mean(), plos_one['Cost'].median(), plos_one['Cost'].std()))
print("This is JBC's mean {}, median {}, and standard deviation {}".format(jbc['Cost'].mean(), jbc['Cost'].median(), jbc['Cost'].std()))
print("This is Neuroimage's mean {}, median {}, and standard deviation {}".format(neuroimage['Cost'].mean(), neuroimage['Cost'].median(), neuroimage['Cost'].std()))
print("This is NAR's mean {}, median {}, and standard deviation {}".format(nar['Cost'].mean(), nar['Cost'].median(), nar['Cost'].std()))
print("This is Plos Pathogen's mean {}, median {}, and standard deviation {}".format(Plos_pathogens['Cost'].mean(), Plos_pathogens['Cost'].median(), Plos_pathogens['Cost'].std()))
# Out:
# /Users/bryancorder/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/bryancorder/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/bryancorder/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
